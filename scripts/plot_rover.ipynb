# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('rover_vel.txt') as f:
    lines = f.readlines()
    x = [line.split()[0] for line in lines]
    y = [line.split()[1] for line in lines]

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('rover_state.txt')


x = data[:, 0]
y = data[:, 1]
v = data[:,2]
t = data[:,3]
plt.plot(x, y,'g--')
plt.show()

# %% [markdown]
# ### MPC OBS AVOID

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_3.txt')


x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1610.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1710_5.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1710_6.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %% [markdown]
#  ### FOR TESTING PURPOSES

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1710_7.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1710_11.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('mpc_rover_state_obs_avoid_1710_13.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()

# %% [markdown]
# ### PID NAIVE OBS AVOID

# %%
import numpy  as np
import matplotlib.pyplot as plt
data = np.loadtxt('pid_rover_state_naive_obs_avoid_2_11_1.txt')

x = data[:, 0]
y = data[:, 1]
v = data[:,2]
w = data[:,3]
t = data[:,4]
plt.plot(y,x,'g--')
plt.show()
plt.plot(t,v,'r--')
plt.show()
plt.plot(t,w,'b--')
plt.show()
